# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import nltk
nltk.download('punkt')
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords                            
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.probability import FreqDist

import requests
import csv
from bs4 import BeautifulSoup
from urllib.request import urlopen

from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
browser = webdriver.Chrome('chromedriver',options=options)
from selenium.webdriver.common.keys import Keys

import unittest

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains

import re

from scrapy import Selector  

from selenium.webdriver import Firefox
from selenium.webdriver.firefox.options import Options

import time
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import TimeoutException


import scrapy
from scrapy.crawler import CrawlerProcess

import json
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ingbg\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ingbg\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
def Beauty(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    return soup

# %% [markdown]
# ## - Exercici 1
#
# Realitza web scraping de dues de les tres pàgines web proposades utilitzant BeautifulSoup primer i Selenium després.
#
# - http://quotes.toscrape.com
#
# - https://www.bolsamadrid.es
#
# - www.wikipedia.es (fes alguna cerca primer i escrapeja algun contingut)

# %%
url_quotes = 'http://quotes.toscrape.com'

# %%
page = requests.get(url_quotes)
page
# Out:
# <Response [200]>

# %%
print(page.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# ...

# %%
soup_quotes = Beauty(url_quotes)
soup_quotes
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
# ...

# %%
soup_quotes.title
# Out:
# <title>Quotes to Scrape</title>

# %%
soup_quotes.title.string
# Out:
# 'Quotes to Scrape'

# %% [markdown]
# Inspeccionant al navegador, localitzem que el text es troba dins la class="quote":
#
# #<div class="quote" itemscope itemtype="http://schema.org/CreativeWork"

# %%
#cada página hi ha 10 textes que s'anomenen igual
quote_elements = soup_quotes.find_all('div', class_='quote', itemscope="")
len(quote_elements)
# Out:
# 10

# %%
quote = []; author = [];

for x in quote_elements:
    quote.append(x.find('span', class_='text').string)
    author.append(x.find('small', class_='author').string)

# %%
quote_list = list(zip(quote, author))

df_quotes = pd.DataFrame({
    'Quote': quote,
    'Author': author
})

df_quotes.head(10)
# Out:
#                                                Quote             Author
# 0  “The world as we have created it is a process ...    Albert Einstein
# 1  “It is our choices, Harry, that show what we t...       J.K. Rowling
# 2  “There are only two ways to live your life. On...    Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...        Jane Austen
# 4  “Imperfection is beauty, madness is genius and...     Marilyn Monroe
# 5  “Try not to become a man of success. Rather be...    Albert Einstein
# 6  “It is better to be hated for what you are tha...         André Gide
# 7  “I have not failed. I've just found 10,000 way...   Thomas A. Edison
# 8  “A woman is like a tea bag; you never know how...  Eleanor Roosevelt
# 9  “A day without sunshine is like, you know, nig...       Steve Martin

# %%
# Scraping con Selenium

browser = webdriver.Chrome('chromedriver', options=options)
browser.get(url_quotes)

text = browser.find_elements(By.CLASS_NAME,'text')
name = browser.find_elements(By.CLASS_NAME,'author')

quote = []; author = [];

for value in text:
    quote.append(value.text)

for value in name:
    author.append(value.text)

browser.close()

quote_list = list(zip(quote, author))

df_quotes = pd.DataFrame({
    'Quote': quote,
    'Author': author
})

df_quotes.head()
# Out:
#                                                Quote           Author
# 0  “The world as we have created it is a process ...  Albert Einstein
# 1  “It is our choices, Harry, that show what we t...     J.K. Rowling
# 2  “There are only two ways to live your life. On...  Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...      Jane Austen
# 4  “Imperfection is beauty, madness is genius and...   Marilyn Monroe

# %%
url_wiki = 'https://en.wikipedia.org/wiki/Artificial_intelligence'
soup_wiki = Beauty(url_wiki)
soup_wiki.title.string
# Out:
# 'Artificial intelligence - Wikipedia'

# %%
text = ''
for paragraph in soup_wiki.find_all('p'):
    text += paragraph.text
    
text
# Out:
# '\nArtificial intelligence (AI) is intelligence demonstrated by machines, as opposed to intelligence of humans and other animals. Example tasks in which this is done include speech recognition, computer vision, translation between (natural) languages, as well as other mappings of inputs.\nAI applications include advanced web search engines (e.g., Google Search), recommendation systems (used by YouTube, Amazon, and Netflix), understanding human speech (such as Siri and Alexa), self-driving cars (e.g., Waymo and Tesla), generative or creative tools (ChatGPT and AI art), automated decision-making, and competing at the highest level in strategic game systems (such as chess and Go).[1]\nAs machines become increasingly capable, tasks considered to require "intelligence" are often removed from the definition of AI, a phenomenon known as the AI effect. For instance, optical character recognition is frequently excluded from things considered to be AI, having become a routine technology.[2]\nA
# ...

# %%
text = text.replace('\n', '')

text
# Out:
# 'Artificial intelligence (AI) is intelligence demonstrated by machines, as opposed to intelligence of humans and other animals. Example tasks in which this is done include speech recognition, computer vision, translation between (natural) languages, as well as other mappings of inputs.AI applications include advanced web search engines (e.g., Google Search), recommendation systems (used by YouTube, Amazon, and Netflix), understanding human speech (such as Siri and Alexa), self-driving cars (e.g., Waymo and Tesla), generative or creative tools (ChatGPT and AI art), automated decision-making, and competing at the highest level in strategic game systems (such as chess and Go).[1]As machines become increasingly capable, tasks considered to require "intelligence" are often removed from the definition of AI, a phenomenon known as the AI effect. For instance, optical character recognition is frequently excluded from things considered to be AI, having become a routine technology.[2]Artificia
# ...

# %%
text = text.lower()
tokenized_word = word_tokenize(text)

tokenized_word = [w for w in tokenized_word if w.isalpha()]

stop_words = set(stopwords.words("english"))

filtered_word = [w for w in tokenized_word if w not in stop_words]

fdist = FreqDist(filtered_word)

word_df = pd.DataFrame(fdist.most_common(10))
word_df.columns = ['Common_words','count']
word_df.style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_92861_row0_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_92861_row1_col1 {
#   background-color: #fea145;
#   color: #000000;
# }
# #T_92861_row2_col1 {
#   background-color: #ffe58f;
#   color: #000000;
# }
# #T_92861_row3_col1 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_92861_row4_col1 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_92861_row5_col1 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_92861_row6_col1 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_92861_row7_col1 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_92861_row8_col1, #T_92861_row9_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_92861">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92861_level0_col0" class="col_heading level0 col0" >Common_words</th>
# ...

# %%
browser = webdriver.Chrome('chromedriver',options=options)
browser.get(url_wiki)

wiki = '' 

for i in range(1,20) :
    try: 
        # //*[@id="mw-content-text"]/div[1]/p[2]/b[1]
        
        text = browser.find_element("xpath", f'//*[@id="mw-content-text"]/div[1]/p[{i}]')
        wiki +=  text.text
    except : print('Error ' + i ) ; continue

wiki
# Out:
# 'Artificial intelligence (AI) is intelligence demonstrated by machines, as opposed to intelligence of humans and other animals. Example tasks in which this is done include speech recognition, computer vision, translation between (natural) languages, as well as other mappings of inputs.AI applications include advanced web search engines (e.g., Google Search), recommendation systems (used by YouTube, Amazon, and Netflix), understanding human speech (such as Siri and Alexa), self-driving cars (e.g., Waymo and Tesla), generative or creative tools (ChatGPT and AI art), automated decision-making, and competing at the highest level in strategic game systems (such as chess and Go).[1]As machines become increasingly capable, tasks considered to require "intelligence" are often removed from the definition of AI, a phenomenon known as the AI effect. For instance, optical character recognition is frequently excluded from things considered to be AI, having become a routine technology.[2]Artificia
# ...

# %%
text = wiki.lower()
tokenized_word = word_tokenize(text)

tokenized_word = [w for w in tokenized_word if w.isalpha()]

fdist = FreqDist(tokenized_word)

word_df = pd.DataFrame(fdist.most_common(15))
word_df.columns = ['Common_words','count']
word_df
# Out:
#     Common_words  count
# 0            the     72
# 1            and     58
# 2             of     43
# 3             to     32
# 4             in     30
# 5             ai     28
# 6             as     22
# 7   intelligence     18
# 8              a     18
# 9             by     16
# 10          that     13
# 11    artificial     12
# 12           was     10
# 13          this      9
# 14           for      9

# %% [markdown]
# ## - Exercici 2
#
# Documenta el teu conjunt de dades generat amb la informació que tenen els diferents arxius de Kaggle.
# A manera d'exemple del que es demana pots consultar aquest enllaç:
#
# ->https://www.kaggle.com/datasets/vivovinco/20212022-football-team-stats.

# %%
df_quotes.head(10)
# Out:
#                                                Quote             Author
# 0  “The world as we have created it is a process ...    Albert Einstein
# 1  “It is our choices, Harry, that show what we t...       J.K. Rowling
# 2  “There are only two ways to live your life. On...    Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...        Jane Austen
# 4  “Imperfection is beauty, madness is genius and...     Marilyn Monroe
# 5  “Try not to become a man of success. Rather be...    Albert Einstein
# 6  “It is better to be hated for what you are tha...         André Gide
# 7  “I have not failed. I've just found 10,000 way...   Thomas A. Edison
# 8  “A woman is like a tea bag; you never know how...  Eleanor Roosevelt
# 9  “A day without sunshine is like, you know, nig...       Steve Martin

# %% [markdown]
# **About Dataset df_quotes**
#
# Context
#
# This dataset contains quotes from a scraped website.
#
# Content
#
# +10 rows and 2 columns. Columns' description are listed below.
#
#     Quote : Quotation
#     Author : Person who made the quotation
#
# Acknowledgements
#
# Data from http://quotes.toscrape.com/

# %% [markdown]
# **About Dataset word_df**
#
# Context
#
# This dataset contains description about Artificial Intelligence.
#
# Content
#
# +15 rows and 2 columns. Columns' description are listed below.
#
#     Common_words : The most commun words in order
#     Count : The frequency of repetitions
#
# Acknowledgements
#
# Data from https://en.wikipedia.org/wiki/Artificial_intelligence

# %% [markdown]
# ## - Exercici 3
#
# Tria una pàgina web que tu vulguis i realitza web scraping mitjançant la llibreria Selenium primer i Scrapy després.

# %%
url = 'https://www.solidea.com/es/cat/calcetines/calcetines-de-prevencion'    

opts = Options() 
opts.headless = True # sense interfaç gràfica per a millorar eficiència
browser = Firefox(options=opts) 
    # a continuació definim opció en el cas que la connexió s'esgoti, intentará acceder-hi al cap de 5s.
try:
    browser.get(url)
    time.sleep(5)
except TimeoutException:
    print('new connection try')
    browser.get(url)
    time.sleep(5) 

    # secció específica informació productes
sections= browser.find_elements(By.XPATH,'//html/body/main/section[2]/div/div/div[2]/div[4]/div')
num_sect = len(browser.find_elements(By.XPATH,'//html/body/main/section[2]/div/div/div[2]/div[4]/div'))
products =[]                                  

for r in range(1,1+num_sect):
    # /html/body/main/section[2]/div/div/div[2]/div[4] Xpath on engloba tots els productes
    # /html/body/main/section[2]/div/div/div[2]/div[4]/div[1] Xpath on es troba el primer
    sections= browser.find_element(By.XPATH,'//html/body/main/section[2]/div/div/div[2]/div[4]/div['+str(r)+']')
    elements={}
    elements['name'] = sections.find_element(By.TAG_NAME,'h4').text
    elements['tags'] = [tags.text.strip() for tags in sections.find_elements(By.TAG_NAME,'span')]
    elements['price'] = sections.find_element(By.CLASS_NAME,'product-price').text
    elements['colors'] = [color.get_attribute('alt') for color in sections.find_element(By.CLASS_NAME,'colors')\
                      .find_elements(By.TAG_NAME,'img')]
    products.append(elements)
# Out:
# C:\Users\ingbg\AppData\Local\Temp\ipykernel_20252\3570526265.py:4: DeprecationWarning: headless property is deprecated, instead use add_argument('-headless')
#   opts.headless = True # sense interfaç gràfica per a millorar eficiència

# %%
num_sect #hi ha 20 productes diferents a la pàgina
# Out:
# 20

# %%
products_pd
# Out:
#                                    name  \
# 0                    KAREN KNEE HIGH 70
# 1                 SAVANNAH KNEE HIGH 70
# 2              MISS RELAX MICRO RETE 70
# 3                                ENERGY
# 4                         MISS RELAX 70
# 5                        MISS RELAX 100
# 6                        MISS RELAX 140
# 7                              RELAX 70
# 8   SOCKS FOR YOU MERINO BAMBOO CLASSIC
# 9                             RELAX 140
# 10    SOCKS FOR YOU MERINO BAMBOO FUNNY
# 11              RELAX 140 PUNTA ABIERTA
# 12    SOCKS FOR YOU MERINO BAMBOO RUMBA
# 13               RELAX 70 PUNTA ABIERTA
# 14           SOCKS FOR YOU BAMBOO OPERA
# 15            SOCKS FOR YOU BAMBOO TYPE
# 16          SOCKS FOR YOU BAMBOO SQUARE
# 17           SOCKS FOR YOU BAMBOO MUSIC
# 18            SOCKS FOR YOU BAMBOO POIS
# 19          MINI-MEDIA SCOTTISH 100 DEN
#
#                                                  tags    price  \
# ...

# %%
# Per poder guadar les dades en json 
import json

class JsonWriterPipeline(object):

    def open_spider(self, spider):
        self.file = open('socksresult.jl', 'w')

    def close_spider(self, spider):
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item

# %%
#Scrapy per a automatizar l'extracció de información de la pàgina web i guardar-la en un arxiu JSON
class StockSpider(scrapy.Spider):
    name='socks'
    start_urls=["https://www.solidea.com/es/cat/calcetines/calcetines-de-prevencion"]
    
    custom_settings = {
                  
        'ITEM_PIPELINES': {'__main__.JsonWriterPipeline': 1},  
        'FEED_FORMAT':'json',                                  
        'FEED_URI': 'socksresult.json'             # Saves file of the result    
        }
    def parse(self,response):
        for section in response.xpath('/html/body/main/section[2]/div/div/div[2]/div[4]/div'):
            yield {
                'name':section.xpath('.//figure/img/@alt').get(),
                'price': section.xpath('.//div/a/div/div/text()').get(),
                'tags' : section.xpath('.//div/a/div/span/text()').getall(),
                'colors':section.xpath('.//ul/li/img/@alt').getall()
            }

# %%
# Per evitar error ReactorAlreadyInstalledError: reactor already installed
import sys    
if "twisted.internet.reactor" in sys.modules:
    del sys.modules["twisted.internet.reactor"]

#Iniciar el proces de scraping

process = CrawlerProcess({'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'})
process.crawl(StockSpider)
process.start()
# Out:
# 2023-04-14 14:38:05 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
# 2023-04-14 14:38:05 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.2.0, Python 3.9.15 (main, Nov 24 2022, 14:39:17) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 22.0.0 (OpenSSL 1.1.1s  1 Nov 2022), cryptography 38.0.4, Platform Windows-10-10.0.22621-SP0
# 2023-04-14 14:38:05 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2023-04-14 14:38:05 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-04-14 14:38:05 [scrapy.extensions.telnet] INFO: Telnet Password: 3151f07568a2ce5f
# ...

# %%
import pandas as pd
result = pd.read_json("socksresult.jl", lines=True)

# %%
result
# Out:
#                                    name    price  \
# 0                    Karen Knee High 70  € 18,90
# 1                 Savannah Knee High 70  € 18,90
# 2              Miss Relax Micro Rete 70  € 16,90
# 3                                Energy  € 32,50
# 4                         Miss Relax 70  € 15,90
# 5                        Miss Relax 100  € 17,90
# 6                        Miss Relax 140  € 25,90
# 7                              Relax 70  € 17,90
# 8   Socks For You Merino Bamboo Classic  € 39,00
# 9                             Relax 140  € 40,90
# 10    Socks For You Merino Bamboo Funny  € 40,00
# 11              Relax 140 Punta Abierta  € 40,90
# 12    Socks For You Merino Bamboo Rumba  € 40,00
# 13               Relax 70 Punta Abierta  € 19,90
# 14           Socks for you Bamboo Opera  € 36,00
# 15            Socks for you Bamboo Type  € 37,00
# 16          Socks for you Bamboo Square  € 37,00
# 17           Socks for you Bamboo Music  € 37,00
# ...
